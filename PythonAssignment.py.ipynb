# %%
# Out:
#   File "<ipython-input-2-7547cbb94f64>", line 16
#     plt.title('Relationship Between Temperature and Iced
#                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
import matplotlib
except:
import pip pip.main(['install', 'matplotlib'])
import matplotlib
# Out:
#   File "<ipython-input-1-48ecce1d16d3>", line 2
#     except:
#          ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]
plt.scatter(X,Y)
plt.xlim(0,1000)
plt.ylim(0,100)
#scatter plot color
plt.scatter(X, Y, s=60, c='red', marker='^')
#change axes ranges
plt.xlim(0,1000)
plt.ylim(0,100)
#add title
plt.title('Relationship Between Temperature and Iced Coffee Sales')
#add x and y labels
plt.xlabel('Sold Coffee')
plt.ylabel('Temperature in Fahrenheit')
          #show plot
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-whitegrid')
# Create empty figure
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
# set the x and y axis range
plt.xlim(0, 11)
plt.ylim(-2, 2)
plt.axis('tight')
#add title
plt.title('Plotting data using sin and cos')
# Out:
# Text(0.5, 1.0, 'Plotting data using sin and cos')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('classic')
plt.style.use('seaborn-whitegrid')
# Create some data
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]],
size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
# Plot the data with seaborn
sns.distplot(data['x'])
sns.distplot(data['y']);

# %%
for col in 'xy':
sns.kdeplot(data[col], shade=True)
# Out:
#   File "<ipython-input-6-289ea3336ba8>", line 2
#     sns.kdeplot(data[col], shade=True)
#       ^
# IndentationError: expected an indented block

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
sns.kdeplot(data);
# Out:
# C:\Users\Brian\Anaconda3\New folder\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
with sns.axes_style('white'):
sns.jointplot("x", "y", data, kind='kde');
# Out:
#   File "<ipython-input-9-b398b5c3b913>", line 2
#     sns.jointplot("x", "y", data, kind='kde');
#       ^
# IndentationError: expected an indented block

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde');

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex')

# %%
sns.pairplot(data);

# %%
import plotly.graph_objs as go
import numpy as np
x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y,
contours=dict (coloring='heatmap')),
go.Scatter(x=x, y=y, mode='markers',
marker=dict(color='white', size=3,
opacity= opacity=0.3))], show_link=False)
# Out:
#   File "<ipython-input-13-9fd629a394ea>", line 9
#     opacity= opacity=0.3))], show_link=False)
#                     ^
# SyntaxError: invalid syntax

# %%
import plotly.graph_objs as go
import numpy as np
x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y,contours=dict (coloring='heatmap')),go.Scatter(x=x, y=y, mode='markers',marker=dict(color='white', size=3,opacity= opacity=0.3))], show_link=False)
# Out:
#   File "<ipython-input-14-daf74b148f70>", line 5
#     iplot([go.Histogram2dContour(x=x, y=y,contours=dict (coloring='heatmap')),go.Scatter(x=x, y=y, mode='markers',marker=dict(color='white', size=3,opacity= opacity=0.3))], show_link=False)
#                                                                                                                                                                     ^
# SyntaxError: invalid syntax

# %%
import plotly.graph_objs as go
import numpy as np
x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y,contours=dict (coloring='heatmap')),go.Scatter(x=x, y=y, mode='markers', marker=dict(color='white', size=3,opacity= opacity=0.3))], show_link=False)
# Out:
#   File "<ipython-input-15-b2cb19c11155>", line 5
#     iplot([go.Histogram2dContour(x=x, y=y,contours=dict (coloring='heatmap')),go.Scatter(x=x, y=y, mode='markers', marker=dict(color='white', size=3,opacity= opacity=0.3))], show_link=False)
#                                                                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
import plotly.graph_objs as go
import numpy as np
x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y,contours=dict (coloring='heatmap')),go.Scatter(x=x, y=y, mode='markers',markers=dict(color='white', size=3,opacity= opacity=0.3))], show_link=False)
# Out:
#   File "<ipython-input-16-9e8848f68284>", line 5
#     iplot([go.Histogram2dContour(x=x, y=y,contours=dict (coloring='heatmap')),go.Scatter(x=x, y=y, mode='markers',markers=dict(color='white', size=3,opacity= opacity=0.3))], show_link=False)
#                                                                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.plot({'data': [{'y': [14, 22, 30,44]}],
'layout': {'title': 'Offline Plotly', 'font':
dict(size=16)}}, image='png')
Out[90]: 'file:///home/nbuser/library/temp-plot.html'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-b95df18b993f> in <module>
# ----> 1 import plotly.offline as offline
#       2 import plotly.graph_objs as go
#       3 offline.plot({'data': [{'y': [14, 22, 30,44]}],
#       4 'layout': {'title': 'Offline Plotly', 'font':
#       5 dict(size=16)}}, image='png')
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.plot({'data': [{'y': [14, 22, 30,44]}],
'layout': {'title': 'Offline Plotly', 'font':
dict(size=16)}}, image='png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-c99872ac2329> in <module>
# ----> 1 import plotly.offline as offline
#       2 import plotly.graph_objs as go
#       3 offline.plot({'data': [{'y': [14, 22, 30,44]}],
#       4 'layout': {'title': 'Offline Plotly', 'font':
#       5 dict(size=16)}}, image='png')
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import plot.ly.offline as offline
import plot.ly.graph_objs as go
offline.plot({'data': [{'y': [14, 22, 30,44]}],
'layout': {'title': 'Offline Plotly', 'font':
dict(size=16)}}, image='png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-b6f0196b5123> in <module>
# ----> 1 import plot.ly.offline as offline
#       2 import plot.ly.graph_objs as go
#       3 offline.plot({'data': [{'y': [14, 22, 30,44]}],
#       4 'layout': {'title': 'Offline Plotly', 'font':
#       5 dict(size=16)}}, image='png')
#
# ModuleNotFoundError: No module named 'plot'

# %%
import plotly.offline as offline
    import plotly.graph_objs as go
    offline.plot({'data': [{'y': [14, 22, 30,44]}],
    'layout': {'title': 'Offline Plotly', 'font':
    dict(size=16)}}, image='png')
# Out:
#   File "<ipython-input-20-f4ac8b519a66>", line 2
#     import plotly.graph_objs as go
#     ^
# IndentationError: unexpected indent

# %%
import plotly.offline as offline
import plotly.graph_objs as go
    offline.plot({'data': [{'y': [14, 22, 30,44]}],
    'layout': {'title': 'Offline Plotly', 'font':
    dict(size=16)}}, image='png')
# Out:
#   File "<ipython-input-21-56ca3c673273>", line 3
#     offline.plot({'data': [{'y': [14, 22, 30,44]}],
#     ^
# IndentationError: unexpected indent

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.plot({'data': [{'y': [14, 22, 30,44]}],
'layout': {'title': 'Offline Plotly', 'font':
dict(size=16)}}, image='png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-c99872ac2329> in <module>
# ----> 1 import plotly.offline as offline
#       2 import plotly.graph_objs as go
#       3 offline.plot({'data': [{'y': [14, 22, 30,44]}],
#       4 'layout': {'title': 'Offline Plotly', 'font':
#       5 dict(size=16)}}, image='png')
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import pandas as pd import numpy as np
df = pd.DataFrame(np.random.randn(200,6),index= pd.date_
range('1/9/2009', periods=200), columns= list('ABCDEF'))
df.plot(figsize=(20, 10)).legend(bbox_to_anchor=(1, 1))
# Out:
#   File "<ipython-input-23-a719c9e67b5d>", line 1
#     import pandas as pd import numpy as np
#                              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd 
import numpy as np
df = pd.DataFrame(np.random.randn(200,6),index= pd.date_
range('1/9/2009', periods=200), columns= list('ABCDEF'))
df.plot(figsize=(20, 10))import pandas as pd
import numpy as npimport pandas as pd
import numpy as np
# Out:
#   File "<ipython-input-24-e6586d346a19>", line 4
#     range('1/9/2009', periods=200), columns= list('ABCDEF'))
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd 
import numpy as np
df = pd.DataFrame(np.random.randn(200,6),index= pd.date_range('1/9/2009', periods=200), columns= list('ABCDEF'))
df.plot(figsize=(20, 10)).legend(bbox_to_anchor=(1, 1))

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May'])
df.plot.bar(figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb',
'March','April', 'May']) df.plot.bar(stacked=True,
figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))
# Out:
#   File "<ipython-input-27-721c98e8b213>", line 3
#     'March','April', 'May']) df.plot.bar(stacked=True,
#                               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May']) 
df.plot.bar(stacked=True,figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May']) 
df.plot.barh(stacked=True,figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May'])
df.plot.hist(bins= 20, figsize=(10,8)).legend
bbox_to_anchor=(1.2, 1))
# Out:
#   File "<ipython-input-30-8c5eccd04c53>", line 4
#     bbox_to_anchor=(1.2, 1))
#                            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May'])
df.plot.hist(bins= 20, figsize=(10,8)).legendbbox_to_anchor=(1.2, 1))
# Out:
#   File "<ipython-input-31-5a3f447e9a6b>", line 3
#     df.plot.hist(bins= 20, figsize=(10,8)).legendbbox_to_anchor=(1.2, 1))
#                                                                         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May'])
df.plot.hist(bins= 20, figsize=(10,8)).legendbbox_to_anchor=(1.2, 1)

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'April':np.random.randn(1000)+1,'May':np.random.randn(1000),'June': np.random.randn(1000) - 1}, columns=['April','May', 'June'])
df.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019758BD3048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000197588B6A88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019758896988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019758B34B08>]],
#       dtype=object)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','March','April', 'May'])
df.plot.box()

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(20,5),columns= ['Jan','Feb','March','April', 'May'])
df.plot.area(figsize=(6, 4)).legend(bbox_to_anchor=(1.3, 1))

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(20,5),columns= ['Jan','Feb','March','April', 'May'])
df.plot.scatter(x='Feb', y='Jan', title='Temperature over two months ')
